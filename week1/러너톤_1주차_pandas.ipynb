# %%
import pandas as pd
import numpy as np

# %%
year= ['2019','2020','2021','2022']
result = pd.Series(year)

print("Type : ", type(result))
print(result)
# Out:
# Type :  <class 'pandas.core.series.Series'>
# 0    2019
# 1    2020
# 2    2021
# 3    2022
# dtype: object

# %%
year= ['2019','2020','2021','2022']
idx = ['a','b','c','d']
result = pd.Series(data = year,index = idx, name ='Year')

print("Type : ", type(result))
print(result)
# Out:
# Type :  <class 'pandas.core.series.Series'>
# a    2019
# b    2020
# c    2021
# d    2022
# Name: Year, dtype: object

# %%
score={'Kim': 85, 'Han' : 89, 'Lee':99, 'Choi':70}
result = pd.Series(data=score, name ='Score')
print(result)
# Out:
# Kim     85
# Han     89
# Lee     99
# Choi    70
# Name: Score, dtype: int64

# %%
score={'Kim': 85, 'Han' : 89, 'Lee':99, 'Choi':70}
result = pd.Series(data=score)
print(result)

print('\nIndex :', result.index)
print('values :', result.values)
print('dtype :', result.dtype)
print('name :', result.name)
print('index_name :', result.index.name)

# result의 이름과 인덱스 이름 설정(변경)
result.name = "happy"
result.index.name = 'No.'
print()
print('Index :', result.name)
print('Index :', result.index.name)
# Out:
# Kim     85
# Han     89
# Lee     99
# Choi    70
# dtype: int64
#
# Index : Index(['Kim', 'Han', 'Lee', 'Choi'], dtype='object')
# values : [85 89 99 70]
# dtype : int64
# name : None
# index_name : None
#
# Index : happy
# Index : No.

# %%
score = {'name' : ['Jessi', 'Emma', 'Alex', 'Tom'],
         'score' : [100,95, 80,85],
         'grade' : ['A','A','B','B'],
         'subject' : ['python','java','python','C']}

df = pd.DataFrame(score)

print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     name  score grade subject
# 0  Jessi    100     A  python
# 1   Emma     95     A    java
# 2   Alex     80     B  python
# 3    Tom     85     B       C

# %%
print("Index : ", df.index)
print("columns : ", df.columns)
print("values : \n", df.values)
# Out:
# Index :  RangeIndex(start=0, stop=4, step=1)
# columns :  Index(['name', 'score', 'grade'], dtype='object')
# values :
#  [['Jessi' 100 'A']
#  ['Emma' 95 'A']
#  ['Alex' 80 'B']
#  ['Tom' 85 'B']]

# %%
print("Index : ", df.dtypes)
print("columns : ", df.shape)
# Out:
# Index :  name     object
# score     int64
# grade    object
# dtype: object
# columns :  (4, 3)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   score    4 non-null      int64
#  2   grade    4 non-null      object
#  3   subject  4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes
# None

# %%
print(df.describe())
# Out:
#             score
# count    4.000000
# mean    90.000000
# std      9.128709
# min     80.000000
# 25%     83.750000
# 50%     90.000000
# 75%     96.250000
# max    100.000000

# %%
df.sample(frac=0.3)
# Out:
#    name  score grade subject
# 1  Emma     95     A    java

# %%
score = {'name' : ['Jessi', 'Emma', 'Alex', 'Tom'],
         'score' : [100,95, 80,85],
         'age' : [20,25,21,22],
         'grade' : ['A','A','B','B'],
         'subject' : ['python','java','python','C']}

score_df = pd.DataFrame(score)
print(score_df)
# Out:
#     name  score  age grade subject
# 0  Jessi    100   20     A  python
# 1   Emma     95   25     A    java
# 2   Alex     80   21     B  python
# 3    Tom     85   22     B       C

# %%
print(score_df.describe())
# Out:
#             score        age
# count    4.000000   4.000000
# mean    90.000000  22.000000
# std      9.128709   2.160247
# min     80.000000  20.000000
# 25%     83.750000  20.750000
# 50%     90.000000  21.500000
# 75%     96.250000  22.750000
# max    100.000000  25.000000

# %%
print(score_df[['grade', 'subject']].describe())
# Out:
#        grade subject
# count      4       4
# unique     2       3
# top        A  python
# freq       2       2

# %%
print(df.describe(include ='all'))
# Out:
#          name       score grade subject
# count       4    4.000000     4       4
# unique      4         NaN     2       3
# top     Jessi         NaN     A  python
# freq        1         NaN     2       2
# mean      NaN   90.000000   NaN     NaN
# std       NaN    9.128709   NaN     NaN
# min       NaN   80.000000   NaN     NaN
# 25%       NaN   83.750000   NaN     NaN
# 50%       NaN   90.000000   NaN     NaN
# 75%       NaN   96.250000   NaN     NaN
# max       NaN  100.000000   NaN     NaN

# %%
score_df['subject'].unique()
# Out:
# array(['python', 'java', 'C'], dtype=object)

# %%
print(score_df['subject'].value_counts())
# Out:
# subject
# python    2
# java      1
# C         1
# Name: count, dtype: int64

# %%
print(score_df['subject'].value_counts(normalize=True))
# Out:
# subject
# python    0.50
# java      0.25
# C         0.25
# Name: proportion, dtype: float64

# %%
import pandas as pd

# 실습 데이터 생성
score = {'name': ['Jessi', 'Emma', 'Alex', 'Jessi', 'Tom'],
         'score': [100, 95, 80, 85, 97],
         'grade': ['A', 'A', 'B', 'B', 'A'],
         'subject': ['python', 'java', 'python', 'c', 'java']}

c = ['name', 'subject', 'score', 'grade', 'etc']

df = pd.DataFrame(data=score, columns=c)
print(df)
# Out:
#     name subject  score grade  etc
# 0  Jessi  python    100     A  NaN
# 1   Emma    java     95     A  NaN
# 2   Alex  python     80     B  NaN
# 3  Jessi       c     85     B  NaN
# 4    Tom    java     97     A  NaN

# %%
want_col = ['name', 'subject','grade']
want_col_df = df[want_col]

print(want_col_df)
# Out:
#     name subject grade
# 0  Jessi  python     A
# 1   Emma    java     A
# 2   Alex  python     B
# 3  Jessi       c     B
# 4    Tom    java     A

# %%
df['etc']=0
print(df)
# Out:
#     name subject  score grade  etc
# 0  Jessi  python    100     A    0
# 1   Emma    java     95     A    0
# 2   Alex  python     80     B    0
# 3  Jessi       c     85     B    0
# 4    Tom    java     97     A    0

# %%
print(df.loc[1])
print(df.loc[[0,2,4]]) #여러행을 추출할려면 리스트 형태로 전달

row_idx =[1,2,4]
col_idx = ['name', 'subject', 'grade']

print(df.loc[row_idx, col_idx])
# Out:
# name       Emma
# subject    java
# score        95
# grade         A
# etc           0
# Name: 1, dtype: object
#     name subject  score grade  etc
# 0  Jessi  python    100     A    0
# 2   Alex  python     80     B    0
# 4    Tom    java     97     A    0
#    name subject grade
# 1  Emma    java     A
# 2  Alex  python     B
# 4   Tom    java     A

# %%
df.loc[0]= ['Jessi','java', 70,'C',1]
print(df)
# Out:
#     name subject  score grade  etc
# 0  Jessi    java     70     C    1
# 1   Emma    java     95     A    0
# 2   Alex  python     80     B    0
# 3  Jessi       c     85     B    0
# 4    Tom    java     97     A    0

# %%
score = {'name': ['Jessi', 'Emma', 'Alex', 'Jessi', 'Tom'],
         'score': [100, 95, 80, 85, 97],
         'grade': ['A', 'A', 'B', 'B', 'A'],
         'subject': ['python', 'java', 'python', 'c', 'java']}

c = ['name', 'subject', 'score', 'grade', 'etc']

df = pd.DataFrame(data=score, columns=c)
print(df)
# Out:
#     name subject  score grade  etc
# 0  Jessi  python    100     A  NaN
# 1   Emma    java     95     A  NaN
# 2   Alex  python     80     B  NaN
# 3  Jessi       c     85     B  NaN
# 4    Tom    java     97     A  NaN

# %%
semester_data = pd.Series(['20-01','20-01','20-02','20-01'])
df['semester'] = semester_data
print(df)
# Out:
#     name subject  score grade  etc semester
# 0  Jessi  python    100     A  NaN    20-01
# 1   Emma    java     95     A  NaN    20-01
# 2   Alex  python     80     B  NaN    20-02
# 3  Jessi       c     85     B  NaN    20-01
# 4    Tom    java     97     A  NaN      NaN

# %%
df['high_score'] = df['score'] > 90
print(df)
# Out:
#     name subject  score grade  etc semester  high_score
# 0  Jessi  python    100     A  NaN    20-01        True
# 1   Emma    java     95     A  NaN    20-01        True
# 2   Alex  python     80     B  NaN    20-02       False
# 3  Jessi       c     85     B  NaN    20-01       False
# 4    Tom    java     97     A  NaN      NaN        True

# %%
data = {
    'Name': [
        'Pengelly, Mr. Frederick William', 'Renouf, Mrs. Peter Henry (Lillian Jefferys)',
        'Kantor, Mr. Sinai', 'Andersson, Mrs. Anders Johan (Alfrida Konstant...)',
        'Bjornstrom-Steffansson, Mr. Mauritz Hakan', 'Lines, Miss. Mary Conover',
        'Nysten, Miss. Anna Sofia', 'Lahtinen, Mrs. William (Anna Sylfven)',
        'Dick, Mr. Albert Adrian', 'Dean, Mr. Bertram Frank'
    ],
    'Age': [19, 30, 34, 39, 28, 16, 22, 26, 31, 26]
}

df = pd.DataFrame(data)
df
# Out:
#                                                 Name  Age
# 0                    Pengelly, Mr. Frederick William   19
# 1        Renouf, Mrs. Peter Henry (Lillian Jefferys)   30
# 2                                  Kantor, Mr. Sinai   34
# 3  Andersson, Mrs. Anders Johan (Alfrida Konstant...   39
# 4          Bjornstrom-Steffansson, Mr. Mauritz Hakan   28
# 5                          Lines, Miss. Mary Conover   16
# 6                           Nysten, Miss. Anna Sofia   22
# 7              Lahtinen, Mrs. William (Anna Sylfven)   26
# 8                            Dick, Mr. Albert Adrian   31
# 9                            Dean, Mr. Bertram Frank   26

# %%
df['Age_cut1'] = pd.cut(df['Age'],bins=[0,18,25,40,100],labels=['미성년자','청년','중년','노년'])
df
# Out:
#                                                 Name  Age Age_cut1
# 0                    Pengelly, Mr. Frederick William   19       청년
# 1        Renouf, Mrs. Peter Henry (Lillian Jefferys)   30       중년
# 2                                  Kantor, Mr. Sinai   34       중년
# 3  Andersson, Mrs. Anders Johan (Alfrida Konstant...   39       중년
# 4          Bjornstrom-Steffansson, Mr. Mauritz Hakan   28       중년
# 5                          Lines, Miss. Mary Conover   16     미성년자
# 6                           Nysten, Miss. Anna Sofia   22       청년
# 7              Lahtinen, Mrs. William (Anna Sylfven)   26       중년
# 8                            Dick, Mr. Albert Adrian   31       중년
# 9                            Dean, Mr. Bertram Frank   26       중년

# %%
import numpy as np

# %%
df['Age_cut2'] = np.where(df['Age']<=18,'미성년자',
                np.where(df['Age']<=23,'청년',
                np.where(df['Age']<=40,'중년','노년')))

# %%
df
# Out:
#                                                 Name  Age Age_cut1 Age_cut2
# 0                    Pengelly, Mr. Frederick William   19       청년       청년
# 1        Renouf, Mrs. Peter Henry (Lillian Jefferys)   30       중년       중년
# 2                                  Kantor, Mr. Sinai   34       중년       중년
# 3  Andersson, Mrs. Anders Johan (Alfrida Konstant...   39       중년       중년
# 4          Bjornstrom-Steffansson, Mr. Mauritz Hakan   28       중년       중년
# 5                          Lines, Miss. Mary Conover   16     미성년자     미성년자
# 6                           Nysten, Miss. Anna Sofia   22       청년       청년
# 7              Lahtinen, Mrs. William (Anna Sylfven)   26       중년       중년
# 8                            Dick, Mr. Albert Adrian   31       중년       중년
# 9                            Dean, Mr. Bertram Frank   26       중년       중년

# %%
df.loc[6] = ['Jina', 'python', 100,'A', 1, '20-02', True]
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-54cc579f6898> in <cell line: 0>()
# ----> 1 df.loc[6] = ['Jina', 'python', 100,'A', 1, '20-02', True]
#       2 print(df)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#     912
#     913     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1930
#    1931             if missing:
# -> 1932                 self._setitem_with_indexer_missing(indexer, value)
#    1933                 return
#    1934
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2304                     # must have conforming columns
#    2305                     if len(value) != len(self.obj.columns):
# -> 2306                         raise ValueError("cannot set a row with mismatched columns")
#    2307
#    2308                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %%
df
# Out:
#     name subject  score grade semester  high_score
# 0  Jessi  python    100     A    20-01        True
# 1   Emma    java     95     A    20-01        True
# 2   Alex  python     80     B    20-02       False
# 3  Jessi       c     85     B    20-01       False
# 4    Tom    java     97     A      NaN        True

# %%
df.drop(columns=['etc'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-87ef63dfeb7d> in <cell line: 0>()
# ----> 1 df.drop(columns=['etc'], inplace=True)
#       2 print(df)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['etc'] not found in axis"

# %%
print(df)
# Out:
#     name subject  score grade semester  high_score
# 0  Jessi  python    100     A    20-01        True
# 1   Emma    java     95     A    20-01        True
# 2   Alex  python     80     B    20-02       False
# 3  Jessi       c     85     B    20-01       False
# 4    Tom    java     97     A      NaN        True

# %%
df = pd.DataFrame(data = np.arange(18).reshape(6,3),
                  index = ['a','b','c','d','e','f'],
                  columns = ['col1','col2','col3'])

df['col4'] = pd.Series(data = [1.7, 1.2, 2.4],
                       index = ['a','e','c'])
df.loc['c']=None
print(df)
# Out:
#    col1  col2  col3  col4
# a   0.0   1.0   2.0   1.7
# b   3.0   4.0   5.0   NaN
# c   NaN   NaN   NaN   NaN
# d   9.0  10.0  11.0   NaN
# e  12.0  13.0  14.0   1.2
# f  15.0  16.0  17.0   NaN

# %%
print(df.isnull())
# Out:
#     col1   col2   col3   col4
# a  False  False  False  False
# b  False  False  False   True
# c   True   True   True   True
# d  False  False  False   True
# e  False  False  False  False
# f  False  False  False   True

# %%
print(df.isnull().sum(axis=1))
# Out:
# a    0
# b    1
# c    4
# d    1
# e    0
# f    1
# dtype: int64

# %%
print(df.dropna())
# Out:
#    col1  col2  col3  col4
# a   0.0   1.0   2.0   1.7
# e  12.0  13.0  14.0   1.2

# %%
print(df.dropna(how='all'))
# Out:
#    col1  col2  col3  col4
# a   0.0   1.0   2.0   1.7
# b   3.0   4.0   5.0   NaN
# d   9.0  10.0  11.0   NaN
# e  12.0  13.0  14.0   1.2
# f  15.0  16.0  17.0   NaN

# %%
print(df.dropna(axis='index'))
# Out:
#    col1  col2  col3  col4
# a   0.0   1.0   2.0   1.7
# e  12.0  13.0  14.0   1.2

# %%
df['col5']=None
print(df)
# Out:
#    col1  col2  col3  col4  col5
# a   0.0   1.0   2.0   1.7  None
# b   3.0   4.0   5.0   NaN  None
# c   NaN   NaN   NaN   NaN  None
# d   9.0  10.0  11.0   NaN  None
# e  12.0  13.0  14.0   1.2  None
# f  15.0  16.0  17.0   NaN  None

# %%
print(df.dropna(axis='columns', how='all'))
# Out:
#    col1  col2  col3  col4
# a   0.0   1.0   2.0   1.7
# b   3.0   4.0   5.0   NaN
# c   NaN   NaN   NaN   NaN
# d   9.0  10.0  11.0   NaN
# e  12.0  13.0  14.0   1.2
# f  15.0  16.0  17.0   NaN

# %%
df.dropna(how='all', inplace =True)
df.dropna(axis =1, how = 'all', inplace =True)
df.iloc[:2, 0] = np.nan
df.iloc[:4, 1] = np.nan
print(df)
# Out:
#    col1  col2  col3  col4
# a   NaN   NaN   2.0   1.7
# b   NaN   NaN   5.0   NaN
# d   9.0   NaN  11.0   NaN
# e  12.0   NaN  14.0   1.2
# f  15.0  16.0  17.0   NaN

# %%
col_fill = {
    'col1' : 5,
    'col2' : 10,
    'col3' : 15,
    'col4' : 20
}

print(df.fillna(col_fill))
# Out:
#    col1  col2  col3  col4
# a   5.0  10.0   2.0   1.7
# b   5.0  10.0   5.0  20.0
# d   9.0  10.0  11.0  20.0
# e  12.0  10.0  14.0   1.2
# f  15.0  16.0  17.0  20.0

# %%
mean_fill = {
    'col1' : df['col1'].mean(),
    'col2' : df['col2'].mean(),
    'col3' : df['col3'].mean(),
    'col4' : df['col4'].mean()
}

print(df.fillna(mean_fill))
# Out:
#    col1  col2  col3  col4
# a  12.0  16.0   2.0  1.70
# b  12.0  16.0   5.0  1.45
# d   9.0  16.0  11.0  1.45
# e  12.0  16.0  14.0  1.20
# f  15.0  16.0  17.0  1.45

# %%
# 실습 데이터 생성
d = {'name': ['Jessi', 'Emma', 'Alex', 'Jessi', 'Tom'],
         'score': [100, 95, 80, 85, 97],
         'grade': ['A', 'A', 'B', 'B', 'A'],
         'subject': ['python', 'java', 'python', 'c', 'java']}

df = pd.DataFrame(data=d)
print(df)
# Out:
#     name  score grade subject
# 0  Jessi    100     A  python
# 1   Emma     95     A    java
# 2   Alex     80     B  python
# 3  Jessi     85     B       c
# 4    Tom     97     A    java

# %%
print(df['subject'])
print()
print(df.subject)
# Out:
# 0    python
# 1      java
# 2    python
# 3         c
# 4      java
# Name: subject, dtype: object
#
# 0    python
# 1      java
# 2    python
# 3         c
# 4      java
# Name: subject, dtype: object

# %%
select_col = ['name', 'subject', 'grade']
print(df[select_col])
# Out:
#     name subject grade
# 0  Jessi  python     A
# 1   Emma    java     A
# 2   Alex  python     B
# 3  Jessi       c     B
# 4    Tom    java     A

# %%
df.set_index('name',inplace=True)
print(df)
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Emma      95     A    java
# Alex      80     B  python
# Jessi     85     B       c
# Tom       97     A    java

# %%
df.index.name
# Out:
# 'name'

# %%
df.loc[['Jessi','Emma']]
print(df.loc[['Jessi','Emma']])
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Jessi     85     B       c
# Emma      95     A    java

# %%
print(df.loc[df['score']>=95])
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Emma      95     A    java
# Tom       97     A    java

# %%
print(df.loc[df['subject']=='python'])
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Alex      80     B  python

# %%
print(df[1:4])
# Out:
#        score grade subject
# name
# Emma      95     A    java
# Alex      80     B  python
# Jessi     85     B       c

# %%
df[::2]
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Alex      80     B  python
# Tom       97     A    java

# %%
print(df[:'Alex'])
# Out:
#        score grade subject
# name
# Jessi    100     A  python
# Emma      95     A    java
# Alex      80     B  python

# %%
print(df.loc[:'Emma',['subject','grade']])
# Out:
#       subject grade
# name
# Jessi  python     A
# Emma     java     A

# %%
print(df.iloc[:4,-1])
# Out:
# name
# Jessi    python
# Emma       java
# Alex     python
# Jessi         c
# Name: subject, dtype: object

# %%
score = {'sub1':[3,9,1,1,9],
         'sub2':[2,9,np.nan,np.nan, 8],
         'sub3':[np.nan,1,5,5,7],
         'sub4':[np.nan,3,np.nan,1,np.nan]
        }
df = pd.DataFrame(score)
print(df)
# Out:
#    sub1  sub2  sub3  sub4
# 0     3   2.0   NaN   NaN
# 1     9   9.0   1.0   3.0
# 2     1   NaN   5.0   NaN
# 3     1   NaN   5.0   1.0
# 4     9   8.0   7.0   NaN

# %%
print(df.count(axis=0))
# Out:
# sub1    5
# sub2    3
# sub3    4
# sub4    2
# dtype: int64

# %%
print(df.count(axis=1))
# Out:
# 0    2
# 1    4
# 2    2
# 3    3
# 4    3
# dtype: int64

# %%
sample = {'product':['a','b','a','b','a','b','a','a'],
          'sensor':['s1','s1','s2','s3','s2','s2','s1','s3'],
          'x':np.arange(1,9),
          'y':np.arange(5,13)}

df = pd.DataFrame(data=sample)
print(df)
# Out:
#   product sensor  x   y
# 0       a     s1  1   5
# 1       b     s1  2   6
# 2       a     s2  3   7
# 3       b     s3  4   8
# 4       a     s2  5   9
# 5       b     s2  6  10
# 6       a     s1  7  11
# 7       a     s3  8  12

# %%
grouped_product = df.groupby('product')

# %%
for key, value in grouped_product:
  print(key, type(key))
  print(value,type(value))
# Out:
# a <class 'str'>
#   product sensor  x   y
# 0       a     s1  1   5
# 2       a     s2  3   7
# 4       a     s2  5   9
# 6       a     s1  7  11
# 7       a     s3  8  12 <class 'pandas.core.frame.DataFrame'>
# b <class 'str'>
#   product sensor  x   y
# 1       b     s1  2   6
# 3       b     s3  4   8
# 5       b     s2  6  10 <class 'pandas.core.frame.DataFrame'>

# %%
grouped_product = df.groupby('product').sum()
print(grouped_product)
# Out:
#              sensor   x   y
# product
# a        s1s2s2s1s3  24  44
# b            s1s3s2  12  24

# %%
grouped_product= df.groupby(['product','sensor']).sum()
print(grouped_product)
# Out:
#                 x   y
# product sensor
# a       s1      8  16
#         s2      8  16
#         s3      8  12
# b       s1      2   6
#         s2      6  10
#         s3      4   8

# %%
grouped_product= df.groupby(['product','sensor'])['x'].sum()
print(grouped_product)
# Out:
# product  sensor
# a        s1        8
#          s2        8
#          s3        8
# b        s1        2
#          s2        6
#          s3        4
# Name: x, dtype: int64

# %%
condition = {'x':'max', 'y':'min'}
grouped_product= df.groupby(['product','sensor']).agg(condition)

print(grouped_product)
# Out:
#                 x   y
# product sensor
# a       s1      7   5
#         s2      5   7
#         s3      8  12
# b       s1      2   6
#         s2      6  10
#         s3      4   8

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
}, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'D': ['D8', 'D9', 'D10', 'D11']
}, index=[8, 9, 10, 11])

# df4 생성
df4 = pd.DataFrame({
    'B': ['B2', 'B3', 'B6', 'B7'],
    'D': ['D2', 'D3', 'D6', 'D7'],
    'F': ['F2', 'F3', 'F6', 'F7']
}, index=[2, 3, 6, 7])

# %%
print(df1)
print()
print(df2)
print()
print(df3)
print()
print(df4)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
#
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
#
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
result = pd.concat([df2,df1])
print(result)
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
result = pd.concat([df2,df1], ignore_index=True)
print(result)
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7
# 4  A0  B0  C0  D0
# 5  A1  B1  C1  D1
# 6  A2  B2  C2  D2
# 7  A3  B3  C3  D3

# %%
result=pd.concat([df1,df4])
print(result)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1[:2], df4[3:]])
print(result)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1,df4],axis=1, ignore_index=True)
print(result)
# Out:
#      0    1    2    3    4    5    6
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result=pd.concat([df1,df4])
print(result)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1,df4], join='inner')
print(result)
# Out:
#     B   D
# 0  B0  D0
# 1  B1  D1
# 2  B2  D2
# 3  B3  D3
# 2  B2  D2
# 3  B3  D3
# 6  B6  D6
# 7  B7  D7

# %%
result = pd.concat([df1,df4],axis=1, join='inner')
print(result)
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3
